# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("London.csv")

# %%
df
# Out:
#       Unnamed: 0       Property Name    Price        House Type  \
# 0              0         Queens Road  1675000             House
# 1              1       Seward Street   650000  Flat / Apartment
# 2              2         Hotham Road   735000  Flat / Apartment
# 3              3        Festing Road  1765000             House
# 4              4        Spencer Walk   675000  Flat / Apartment
# ...          ...                 ...      ...               ...
# 3475        3475   One Lillie Square  3350000   New development
# 3476        3476  St. James's Street  5275000  Flat / Apartment
# 3477        3477       Ingram Avenue  5995000             House
# 3478        3478         Cork Street  6300000   New development
# 3479        3479    Courtenay Avenue  8650000             House
#
#       Area in sq ft  No. of Bedrooms  No. of Bathrooms  No. of Receptions  \
# 0              2716                5                 5                  5
# ...

# %%
df.dropna(inplace = True)

# %%
df1 = df.drop(['Unnamed: 0', 'Property Name', 'House Type', 'No. of Bedrooms', 'No. of Bathrooms', 'No. of Receptions', 'Location', 'City/County', 'Postal Code'], axis='columns')

# %%
df1
# Out:
#          Price  Area in sq ft
# 0      1675000           2716
# 1       650000            814
# 2       735000            761
# 3      1765000           1986
# 4       675000            700
# ...        ...            ...
# 3473  19950000           3698
# 3476   5275000           1749
# 3477   5995000           4435
# 3478   6300000           1506
# 3479   8650000           5395
#
# [2518 rows x 2 columns]

# %%
df1.isnull().sum()
# Out:
# Price            0
# Area in sq ft    0
# dtype: int64

# %%
df1['Area in sq ft'].unique()
# Out:
# array([2716,  814,  761, ..., 4435, 1506, 5395])

# %%
df1
# Out:
#          Price  Area in sq ft
# 0      1675000           2716
# 1       650000            814
# 2       735000            761
# 3      1765000           1986
# 4       675000            700
# ...        ...            ...
# 3473  19950000           3698
# 3476   5275000           1749
# 3477   5995000           4435
# 3478   6300000           1506
# 3479   8650000           5395
#
# [2518 rows x 2 columns]

# %%
chosen_idx = np.random.choice(3, size = 4)

# %%
df2 = df1.iloc[chosen_idx]

# %%
df2
# Out:
#      Price  Area in sq ft
# 2   735000            761
# 2   735000            761
# 0  1675000           2716
# 2   735000            761

# %%
plt.title("London house prices")
plt.xlabel("Area in sq ft")
plt.ylabel("Price")
plt.scatter(df2['Area in sq ft'], df2['Price'])
